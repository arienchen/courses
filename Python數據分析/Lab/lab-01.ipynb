# %% [markdown]
# # LAB-01 Jupyter Notebook 基本操作
#
# * 設定 Cell 格式： Code 程式碼 | Markdown 說明 | Raw 原始文字
# * 執行 Python Code 顯示 **Hello World**
# * Edit Mode 指令
# * Command Mode 指令
# * Markdown 貼圖

# %% [markdown]
# ## 程式格(Cell)模式
# * Edit Mode 編輯模式
#   ![image.png](attachment:ef260940-0689-4c97-be26-5b2155e6ada8.png)
#
# * Command Mode 指令模式
#   ![image.png](attachment:6b6edce3-567d-4260-8f6e-ad9e05ffd9b0.png)
#
# **切換方式**
# 1. `Edit Mode`：滑鼠點擊可編輯區
# 2. `Command Mode`：滑鼠點擊程式格左邊或於 `Edit Mode` 時，按 `Esc` 鍵

# %% [markdown]
# ## 輸入及執行
# 1. `Ctrl + Enter`：執行
# 2. `Alt + Enter`：執行，且新增一行程式格

# %%
## TODO 
##   輸入 print("Hello World") 後，按 Ctrl+Enter
# Out:
# Hello World

# %% [markdown]
# ## Edit Mode 編輯指令
# 1. `Esc` 離開編輯模式，回到 Command Mode 指令模式
# 2. **`Shit + Tab`** <font color="red">Contextual Help 內容說明</font>
# 3. `Ctrl + ]` 整行靠右縮排
# 4. `Ctrl + [` 整行靠左縮排
# 5. `Ctrl + a` 選擇全部
# 6. `Ctrl + z` Undo
# 7. `Ctrl + 上` 回到第一個字元最
# 8. `Ctrl + 下` 回到最後一個字元
# 9. `Ctrl + 右` 往右一個字組(word)
# 10. `Ctrl + 左` 往左一個字組(word)

# %%
## TO DO
##    輸入 print( 後
##    按 Shitt-Tab ，或下拉選單 Help | Show Contextual Help 

## 其他函式 open, range

# %% [markdown]
# ## Command Mode 指令模式
# 1. `a` 往上新增一行程式格
# 2. `dd` 刪除程式格
# 3. `b` 往下新增一行程式格
# 4. `c` 複製 Copy
# 5. `v` 貼上 Paste
# 6. `x` 剪下 Cut
# 7. `y` 將程式格設為 Code
# 8. `m` 將程式格設為 Markdown
# 9. `r` 將程式格設為 Raw

# %% [markdown]
# ## Markdown 支援貼圖

# %% [markdown]
# 1. 新增一個程式格(Markdown)
# 2. 直接 copy-paste
#
# ![image.png](attachment:288650b4-6c74-4437-aeb5-917171fd7e22.png)

# %%
## TODO
##   按 Alt+Enter
##   將新的程式格，改為 Markdown
##   按 PrnScn 鍵，或其他複製圖
##   直接 Ctrl-V 貼上
